# %% [markdown]
# # Agenda:
#
# 1. `import` and its various forms
# 2. Standard library (modules that come with Python)
# 3. Start to look at third-party modules and PyPI

# %% [markdown]
# # Modules and imports
#
# If I want to share code that I've written with other people, *or* if I want to use code in a number of different programs, *or* if I want to use code that someone else has written, then I want to use a *module*.
#
# A module is a file containing Python code (basically variable and function definitions) that I can then use inside of my program (or others can use in theirs). This helps us to fulfill the DRY rule -- don't repeat yourself. This has so many advantages!
#
# If there is a module that is already installed on my system, then I can use it in my program with `import`.
#
# ## Two versions of `import`:
#
# - `import mymod` -- this loads a module into Python's memory, and makes all of the names it defined available via attributes. So if it defined a variable `x`, we can get it as `mymod.x`. If it defined a function `hello`, then we can invoke it as `mymod.hello()`.
# - `from mymod import x` -- the `from .. import` syntax doesn't change what is loaded into memory. But it does change what name(s) are defined. In this example, `mymod` will not be defined as a variable. But `x` will be! This means that we won't be able to say `mymod.x`, but we will be able to say `x`. The idea is that if `x` is a name you're going to use often, then you probably don't want to be bogged down writing its full name.

# %% [markdown]
# # More `import` options
#
# There are a few scenarios that people encounter when importing:
#
# - The name is really long, and you would like to have a shorter alias
# - The name conflicts with another name in your system, and you want to avoid that duplication/collision
# - There might be a standard/convention for naming the module
#
# For any/all of these, you can use the `import ... as` syntax. The idea is you say `import mymod as m`, or whatever alias you want to give it. Once you do that, the variable is set to be `m`; you cannot use the original name `mymod`.
#
# We do this all of the time, especially in the data-analysis world. When we start to use Pandas, we won't say `import pandas`. Rather, we'll say `import pandas as pd`.
#
# Another, related `import` possibility is if you want to import a particular name from a module, and give it an alias. For that, you can say `from random import randint as ri`. This imports the entire `random` module, but doesn't assign the `random` variable to it. Rather, the only variable assigned is `ri`, which refers to `random.randint` (not that either name is available right now).

# %% [markdown]
# # Exercise: Guess the name
#
# - Define a list of names (strings), and call it `names`. (You might have people in your family, or planets, or car brands.)
# - Use `random.choice`, a function in the `random` module, to select one name at random from this list. Assign that name to `secret`. Also, don't invoke `random.choice` with that name -- instead, use just `ch`.
# - Define an empty list, `already_guessed`.
# - Define `guess_counter`, to see how many guesses the person has given so far.
# - With those in place, repeatedly ask the user to guess the secret name:
#     - If they guess it, stop asking and report how many guesses it took.
#     - If they guess a name that is *not* in `names`, then scold them and tell them to try again.
#     - If they guess a name that they have already tried, and is in `already_guessed`, then scold them, and let them try again. (You don't need to increment `guess_counter` for this.
#     - If they guess a name that is in `names`, but is not the secret, then add that name to `already_guessed` and increment `guess_counter`.
#
# https://practice.lernerpython.com/classroom/ce06963a8d/ex-43

# %%
# I want the "choice" function from "random", aliased to "ch"

from random import choice as ch

names = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

secret = ch(names)
print(secret)

already_guessed = []
guess_counter = 1

while True:
    guess = input('Enter a guess: ').strip()

    if guess == secret:
        print(f'You got it in {guess_counter} tries!')
        break
    elif guess not in names:   
        print(f'{guess} is not in my list; try again')
    elif guess in already_guessed:
        print(f'You guessed {guess} already!')
    else:
        already_guessed.append(guess)
        guess_counter += 1
        print(f'Nope, not {guess} -- try again.')
# Out:
# Earth
# Enter a guess:  Mercury
# Nope, not Mercury -- try again.
# Enter a guess:  Mars
# Nope, not Mars -- try again.
# Enter a guess:  Earth
# You got it in 3 tries!

# %% [markdown]
# # Standard library
#
# When you download/install Python, you're getting a lot:
#
# - Python language
# - Editor known as IDLE
# - A ton of modules, known as the "standard library."
#
# It includes hundreds of modules (and packages, which are directories containing modules) for all sorts of activities.
#
# The good news with the standard library is that it's standard -- it comes with Python. Which means that if you use a module in the standard library, it's guaranteed that anyone else running your code will also have access to these modules.
#
# However, just because it's standard doesn't mean that it's already loaded. You will need to `import` any module you want from the standard library into your program. Some modules are called "builtins" because they are loaded automatically, and don't require `import`. But that's a small minority of the modules in the standard library.

# %%
import random

# %%
type(random)
# Out:
# module

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %% [markdown]
# # Exercise: Exploring `math`
#
# - Import the `math` module from the standard library.
# - How many names are defined in the module? How many names that do *not* start or end with an underscore (_)?
# - Ask the user to enter the radius of a circle (an integer). Print the area of that circle, given that we can calculate it as pi * r squared. You can use `math.pi` for that.
# - Ask the user to enter a large number. Use the module's documentation at `docs.python.org` to find a function in the module that gives you the "integer square root" -- the integer whose square comes close (without going over) to the number you've entered.
#
# https://practice.lernerpython.com/classroom/ce06963a8d/ex-42

# %%
import math

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.isqrt(23)
# Out:
# 4

# %%
len(dir(math))
# Out:
# 67

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
counter = 0
for one_name in dir(math):
    if one_name[0] == '_' or one_name[-1] == '_':
        continue

    counter += 1

print(counter)
# Out:
# 62

# %%
counter = 0
for one_name in dir(math):
    if one_name.startswith('_') or one_name.endswith('_'):
        continue

    counter += 1

print(counter)
# Out:
# 62

# %%
# Ask the user to enter the radius of a circle (an integer). Print the area of that circle, given that we can calculate it as pi * r squared. You can use math.pi for that.

radius_text = input('Enter radius: ').strip()
radius = int(radius_text)
area = math.pi * radius ** 2

print(f'Area for {radius} is {area}')
# Out:
# Enter radius:  5
# Area for 5 is 78.53981633974483

# %%
# Ask the user to enter a large number. Use the module's documentation at docs.python.org to find a function in the module that gives you the "integer square root" -- the integer whose square comes close (without going over) to the number you've entered.

number_text = input('Enter number: ').strip()
number = int(number_text)

root = math.isqrt(number)

print(f'The integer square root of {number} is {root}.')
# Out:
# Enter number:  71
# The integer square root of 71 is 8.

# %% [markdown]
# # The story so far
#
# - Python comes with a lot of modules
# - We can import one or more of them into our program
# - We can alias them for convenience
#
# What if we want something beyond the standard library?

# %% [markdown]
# # PyPI -- the Python Package Index
#
# - This is a collection of third-party Python packages that you can download and install
# - Anyone can upload a package to PyPI for public distribution
# - You can download and install it onto your computer using a variety of tools, mostly `pip` and `uv`

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/reuven/.local/share/uv/python/cpython-3.14.7-macos-aarch64-none/lib/python314.zip',
#  '/Users/reuven/.local/share/uv/python/cpython-3.14.7-macos-aarch64-none/lib/python3.14',
#  '/Users/reuven/.local/share/uv/python/cpython-3.14.7-macos-aarch64-none/lib/python3.14/lib-dynload',
#  '',
#  '/Users/reuven/Courses/Current/BDTMSD-Python-2026-07/.venv/lib/python3.14/site-packages']

# %%
# !ls /Users/reuven/Courses/Current/BDTMSD-Python-2026-07/.venv/lib/python3.14/site-packages
# Out:
# __pycache__
# _argon2_cffi_bindings
# _cffi_backend.cpython-314-darwin.so
# _plotly_utils
# _virtualenv.pth
# _virtualenv.py
# _yaml
# ada92cb5d92a588d1b93__mypyc.cpython-314-darwin.so
# anyio
# anyio-4.14.2.dist-info
# appnope
# appnope-0.1.4.dist-info
# argon2
# argon2_cffi_bindings-25.1.0.dist-info
# argon2_cffi-25.1.0.dist-info
# arrow
# arrow-1.4.0.dist-info
# asttokens
# asttokens-3.0.2.dist-info
# async_lru
# async_lru-2.3.0.dist-info
# attr
# attrs
# attrs-26.1.0.dist-info
# babel
# babel-2.18.0.dist-info
# beautifulsoup4-4.15.0.dist-info
# bleach
# bleach-6.4.0.dist-info
# bs4
# certifi
# certifi-2026.6.17.dist-info
# cffi
# cffi-2.1.0.dist-info
# charset_normalizer
# charset_normalizer-3.4.9.dist-info
# comm
# comm-0.2.3.dist-info
# contourpy
# contourpy-1.3.3.dist-info
# cycler
# cycler-0.12.1.dist-info
# dateutil
# debugpy
# debugpy-1.8.21.dist-info
# decorator
# decorator-5.3.1.dist-info
# defusedxml
# defusedxml-0.7.1.dist-info
# et_xmlfile
# et_xmlfile-2.0.0.dist-info
# ...

# %%
import rich

# %% [markdown]
# The big thing that `rich` does is provide `rich.print`, a superset of the regular `print` function, which allows you to print in color and with additional snazzy elements.

# %%
rich.print('[yellow on blue]Hello[/yellow on blue], [bold][italic]world[/italic][/bold], :loudly_crying_face: !')
# Out:
# Hello, world, 😭 !
