# %% [markdown]
# # Agenda
#
# - `NaN`
# - Data frames

# %% [markdown]
# # `NaN`
#
# `NaN` is the Pandas way of printing something that is also/often known as `nan`. Both of these are the same, and both stand for "not a number."
#
# The idea is that there are many times when you don't have data, or you do have data that has been corrupted. You don't want to replace those values with 0 or -9999 or something like that, since throw off you
