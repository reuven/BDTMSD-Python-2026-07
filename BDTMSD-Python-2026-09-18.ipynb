# %% [markdown]
# # Agenda
#
# - `NaN`
# - Data frames

# %% [markdown]
# # `NaN`
#
# `NaN` is the Pandas way of printing something that is also/often known as `nan`. Both of these are the same, and both stand for "not a number."
#
# The idea is that there are many times when you don't have data, or you do have data that has been corrupted. You don't want to replace those values with 0 or -9999 or something like that, since throw off your calculations.
#
# Instead, you want to have something that cannot be mistaken for a number!

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# Pandas uses NumPy under the hood -- and all of its data and all dtypes are actually NumPy dtypes

# %%
np.nan
# Out:
# nan

# %%
type(np.nan)  # what kind of value is this?
# Out:
# float

# %%
np.nan + 5
# Out:
# nan

# %%
10 * np.nan
# Out:
# nan

# %%
np.NaN  # Pandas style of writing NaN... this worked until about a year or so ago
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 np.NaN  # Pandas style of writing NaN... this worked until about a year or so ago
#
# File ~/Courses/Current/BDTMSD-Python-2026-07/.venv/lib/python3.14/site-packages/numpy/__init__.py:763, in __getattr__(attr)
#     760     raise AttributeError(__former_attrs__[attr], name=None)
#     762 if attr in __expired_attributes__:
# --> 763     raise AttributeError(
#     764         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     765         f"{__expired_attributes__[attr]}",
#     766         name=None
#     767     )
#     769 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: `np.NaN` was removed in the NumPy 2.0 release. Use `np.nan` instead.

# %% [markdown]
# The notion that `np.nan` can be used in any calculation, but immediately makes that calculation into `nan`,
