# %% [markdown]
# # Agenda
#
# 1. Review "guessing game" exercise
# 2. Ints vs. floats
# 3. Strings
# 4. Methods

# %% [markdown]
# # Exercise review: Guessing game
#
# 1. Define a variable, `secret_number`, which contains an integer.  (Choose a good one!)
# 2. Print `secret_number` for the user, so that we can debug more easily.
# 3. Ask the user to guess the number
# 4. Print one response:
#     - Too high
#     - Too low
#     - You got it
#
# They only have one chance to guess.

# %%
secret_number = 72
print(secret_number)

guess = input('Guess: ')   # input always returns a string

# we need to convert guess to be an integer
# easiest way (I think)

guess = int(guess)  # get a new int based on guess, then assign back to guess

if guess == secret_number:
    print('You got it!')
elif guess < secret_number:
    print('Too low!')
else:  # if neither of the first two was True...
    print('Too high!')
# Out:
# 72
# Guess:  hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       5
#       6 # we need to convert guess to be an integer
#       7 # easiest way (I think)
#       8
# ----> 9 guess = int(guess)  # get a new int based on guess, then assign back to guess
#      10
#      11 if guess == secret_number:
#      12     print('You got it!')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
# this also works (sort of):

guess = int(input('Guess: '))   

# 1. Get input from the user
# 2. Take that input, and feed it to int, getting an integer
# 3. Return that integer to guess

# good news: usually, guess will be an integer
# bad news: if the user enters non-digits, it blows up

# %% [markdown]
# On line 9, we see
#
#     guess = int(guess)
#
# Several things are going on here:
#
# 1. When we use assignment (`=`), it takes the value on the right and assigns it to the variable on the left. It just so happens that the same variable is being used here, but the right-before-left ordering still happens.
# 2. What happens on the right? We ask for the value of `guess`, and then invoke `int` on that. This returns a new integer based on `guess`. So if `guess` is `'123'`, we'll get the integer `123` back.
# 3. The value we get (i.e., the new integer) is then assigned to `guess`.
#
# The upshot is that before that line, `guess` is referring to a string. But after that line, `guess` is referring to an integer.

# %% [markdown]
# # Integers vs. floats
#
# Python (and all computers) support at least two different types of numbers:
#
# - `int` (whole number)
# - `float` (a number with a decimal point)
#
# Why use one or the other? (Other than the use of a decimal point.)
#
# - Floats are not accurate. Also, they are really slow. And, they are limited in their range.
# - Integers might not be able to handle fractional values, but they are super fast and they aren't limited in their size/range.

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
round(0.2 + 0.2, 2)  # give me the answer to this, but rounded to up to 2 decimal places
# Out:
# 0.4

# %%
s = '123'

# %%
int(s)   # get an integer back
# Out:
# 123

# %%
float(s)  # get a float back
# Out:
# 123.0

# %%
10 == 10.0
# Out:
# True

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
int(123.456)   # I get an int, which means chopping off the float (not rounding!)
# Out:
# 123

# %%
int(123.99999)
# Out:
# 123

# %%
round(3.5)
# Out:
# 4

# %%
round(5.5)
# Out:
# 6

# %%
round(4.5)
# Out:
# 4

# %% [markdown]
# # Python's `round` uses "banker's rounding"
#
# We round to the nearest even value. That's to avoid bias if all of our numbers were to round up.

# %% [markdown]
# # Strings
#
# We've already talked a bit about strings, which are the type we use in Python to deal with text. There is *no* character type in Python -- a string describes any text, from zero length (known as the "empty string") to one character to as big as you want.
#
# In Python, the system calls a string `str`.
#
# You've already seen that you can define a string with `''` or `""`, and unlike other languages, Python doesn't care which you use.
#
# You can put any characters you want inside of a string; it handles Unicode (i.e., any character from any language or any emoji) can be in the string.

# %%
s = 'abcdefghijklmnopqrstuvwxyz'

len(s)  # the "len" function takes a string and returns the number of characters
# Out:
# 26

# %%
t = 'abc def'
len(t)
# Out:
# 7

# %% [markdown]
# # What if I have unusual characters in my string?
#
# For example, I might want to have quote characters in my string.
#
# For that, we have a few options:
#
# 1. Put a `\` before the quote, and then it is taken literally, rather than used as a delimiter (i.e., marking the start/end of a string)
# 2. Use the other kind of quote.

# %%
s = 'He's very nice'
# Out:
#   Cell In[23], line 1
#     s = 'He's very nice'
#                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s = "He's very nice"
print(s)
# Out:
# He's very nice

# %%
# using a backslash here is known as "escaping" 
s = 'He\'s very nice'
print(s)
# Out:
# He's very nice

# %%
# if I just put "s" into Jupyter, it'll show me the printed representation of the variable
# this is a great programming/programmer technique
# it's not true in non-Jupyter/non-debugger contexts

s
# Out:
# "He's very nice"

# %%
s = "She says, "Hello""
print(s)
# Out:
#   Cell In[27], line 1
#     s = "She says, "Hello""
#                     ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
# use '' on the outside

s = 'She says, "Hello"'
print(s)
# Out:
# She says, "Hello"

# %%
s
# Out:
# 'She says, "Hello"'

# %%
# what if I have both types of quotes?
# then I need to escape one of them.

s = 'She says, "He\'s very nice"'
print(s)
# Out:
# She says, "He's very nice"

# %%
s
# Out:
# 'She says, "He\'s very nice"'

# %% [markdown]
# You might have noticed that at the end of a line of Python, unlike many other languages, we don't need a `;`. The end of a line is the end of our command.

# %%
# \n means: put a newline character here
# it's really only one character.. but we type two things in order to create it

s = 'abc\ndef\nghi'

print(s)
# Out:
# abc
# def
# ghi

# %%
# let's look at s

s
# Out:
# 'abc\ndef\nghi'

# %%
# how long is this string?

len(s)  # how many characters?
# Out:
# 11

# %%
# another special character is \t, for tab
# it adds enough spaces to go to the next multiple-of-8 column

print('ab\tcdef\thij')
print('k\tlmnop\t\tqr')
# Out:
# ab	cdef	hij
# k	lmnop		qr

# %% [markdown]
# space, \n and \t are all known as "whitespace" characters in the programming world -- they exist, they are characters, they take up space, but we don't see anything -- we just see their effects.

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
len(s)
# Out:
# 26

# %%
# how can I retrieve a character from a string?
# we use [], and put the numeric index in the []
# note that we start to count in Python from 0

s[0]   # this will return the first character
# Out:
# 'a'

# %%
type(s[0])
# Out:
# str

# %%
type(s)
# Out:
# str

# %%
s[1]
# Out:
# 'b'

# %%
s[2]
# Out:
# 'c'

# %%
s[3]
# Out:
# 'd'

# %%
# can I use a variable? sure!

i = 5
s[i]   # we'll now get the 6th letter, which is..
# Out:
# 'f'

# %%
i = len(s)   # let's get the final character!
s[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 i = len(s)   # let's get the final character!
# ----> 2 s[i]
#
# IndexError: string index out of range

# %% [markdown]
# The problem here is: `len(s)` returned 26, the number of characters
#
# But the index starts with 0, which means the final index will be ... 25
#
# This opens the door to a popular error, "the off by one error."
#
# The final character in a string will always be at `len(s) - 1`

# %%
s[ len(s)-1  ]  # this will give us the final letter
# Out:
# 'z'

# %%
# but why work so hard?
s[-1]  # negative indexes start on the right, with -1
# Out:
# 'z'

# %%
s[-2]
# Out:
# 'y'

# %%
s[-26]
# Out:
# 'a'

# %%
s[-27]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 s[-27]
#
# IndexError: string index out of range

# %% [markdown]
# # Time for f-strings
#
# It is super duper annoying to print variable values along with static string content.

# %%
x = 'hello'
y = 123

print('x = ' + x + ', and y = ' + str(y) + '.')   # this is ugly and annoying
# Out:
# x = hello, and y = 123.

# %% [markdown]
# # A better solution -- an f-string!
#
# 1. It's a string, but created in a different way
# 2. The only difference is that we put `f` before the opening quote on the left.
# 3. Inside of the string, if you have `{}`, the contents are evaluated as little Python programs and turned into strings with `str`.
# 4. The result is a string containing your static text + your dynamic text.

# %%
x = 'hello'
y = 123

print(f'x = {x} and y = {y}.')  # much better!
# Out:
# x = hello and y = 123.

# %%
# you can even have expressions inside of the {}

x = 123
y = 456

print(f'{x} + {y} = {x+y}.')
print(f'{x} * {y} = {x*y}.')
# Out:
# 123 + 456 = 579.
# 123 * 456 = 56088.

# %% [markdown]
# # Exercise: Get a character
#
# 1. Ask the user to enter a text string.
# 2. Ask the user to enter an integer, the index of a character we want from the text string.
# 3. If the integer is < 0, give an error message.
# 4. If the integer is > maximum, give an error message.
# 5. Print the index, the string, and the character together, using an f-string.
#
# https://practice.lernerpython.com/classroom/ce06963a8d/ex-5

# %%
text = input('Enter some text: ')
index = input('Enter an index: ')
index = int(index)

# () mean, "run this function"
# {} in an f-string mean, "this is dynamic, and should be replaced in the final string"
# [] next to a string mean, "retrieve this index from the string"

if index < 0:
    print('Too low! Use an index that is at least 0.')
elif index > len(text):
    print(f'Too high! Use an index up to {len(text)}.')
else:
    print(f'Index {index} in {text} is {text[index]}')
