# %% [markdown]
# # Agenda
#
# 1. Q&A
# 2. Review of strings
# 3. Special strings
# 4. Loops

# %%
# all text in Python, no matter how big or small, is handled using strings

s = 'abcdefghij'

type(s)
# Out:
# str

# %%
print(s)
# Out:
# abcdefghij

# %%
# sometimes we want to use special characters
# these are often written with two characters, star
